# %% [markdown]
# # INTRODUCTION
#
# Big Data Sentiment Analysis is the process of analyzing text data to determine whether the sentiment is positive, negative, or neutral.
#
# This project performs sentiment analysis on sample text data using Python and TextBlob library.

# %% [markdown]
# #OBJECTIVES
#
# - To analyze text sentiments
# - To classify sentiments as positive, negative, or neutral
# - To use Python libraries for sentiment analysis
# - To understand text processing techniques

# %% [markdown]
# # TOOLS USED
#
# - Python
# - Pandas
# - TextBlob
# - Google Colab
# - GitHub

# %%
# !pip install textblob

# %% [markdown]
# IMPORT LIBRARIES

# %%
# IMPORT LIBRARIES

import pandas as pd
from textblob import TextBlob

# %%
# SAMPLE TEXT DATA

texts = [
    "I love this product",
    "This is a terrible experience",
    "The service was okay",
    "Amazing performance and great quality",
    "I am very disappointed"
]

df = pd.DataFrame(texts, columns=['Text'])

df
# Out:
#                                     Text
# 0                    I love this product
# 1          This is a terrible experience
# 2                   The service was okay
# 3  Amazing performance and great quality
# 4                 I am very disappointed

# %%
# SENTIMENT ANALYSIS

def get_sentiment(text):

    analysis = TextBlob(text)

    polarity = analysis.sentiment.polarity

    if polarity > 0:
        return "Positive"

    elif polarity < 0:
        return "Negative"

    else:
        return "Neutral"

df['Sentiment'] = df['Text'].apply(get_sentiment)

df
# Out:
#                                     Text Sentiment
# 0                    I love this product  Positive
# 1          This is a terrible experience  Negative
# 2                   The service was okay  Positive
# 3  Amazing performance and great quality  Positive
# 4                 I am very disappointed  Negative

# %% [markdown]
# # CONCLUSION
#
# - Text sentiments were analyzed successfully
# - Positive, Negative, and Neutral sentiments were identified
# - TextBlob library was used for sentiment analysis
# - Sentiment analysis helps understand user opinions from text data
